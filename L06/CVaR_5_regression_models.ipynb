# %% [markdown]
# <a href="https://colab.research.google.com/github/supsi-dacd-isaac/TeachDecisionMakingUncertainty/blob/main/L06/CVaR_5_regression_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1 : import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
# Step 2 : load wine data
wine_quality = pd.read_csv('https://raw.githubusercontent.com/YBIFoundation/Dataset/refs/heads/main/Wine.csv')

names_inputs = ['malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids',  'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue',  'od280', 'proline']
wine_quality.head(200)
# Out:
#      class_label class_name  alcohol  malic_acid   ash  alcalinity_of_ash  \
# 0              1     Barolo    14.23        1.71  2.43               15.6
# 1              1     Barolo    13.20        1.78  2.14               11.2
# 2              1     Barolo    13.16        2.36  2.67               18.6
# 3              1     Barolo    14.37        1.95  2.50               16.8
# 4              1     Barolo    13.24        2.59  2.87               21.0
# ..           ...        ...      ...         ...   ...                ...
# 173            3    Barbera    13.71        5.65  2.45               20.5
# 174            3    Barbera    13.40        3.91  2.48               23.0
# 175            3    Barbera    13.27        4.28  2.26               20.0
# 176            3    Barbera    13.17        2.59  2.37               20.0
# 177            3    Barbera    14.13        4.10  2.74               24.5
#
#      magnesium  total_phenols  flavanoids  nonflavanoid_phenols  \
# 0          127           2.80        3.06                  0.28
# 1          100           2.65        2.76                  0.26
# 2          101           2.80        3.24                  0.30
# 3          113           3.85        3.49                  0.24
# 4          118           2.80        2.69                  0.39
# ..         ...            ...         ...                   ...
# 173         95           1.68        0.61                  0.52
# 174        102           1.80        0.75                  0.43
# 175        120           1.59        0.69                  0.43
# 176        120           1.65        0.68                  0.53
# 177         96           2.05        0.76                  0.56
#
#      proanthocyanins  color_intensity   hue  od280  proline
# 0               2.29             5.64  1.04   3.92     1065
# 1               1.28             4.38  1.05   3.40     1050
# 2               2.81             5.68  1.03   3.17     1185
# 3               2.18             7.80  0.86   3.45     1480
# 4               1.82             4.32  1.04   2.93      735
# ..               ...              ...   ...    ...      ...
# 173             1.06             7.70  0.64   1.74      740
# 174             1.41             7.30  0.70   1.56      750
# 175             1.35            10.20  0.59   1.56      835
# 176             1.46             9.30  0.60   1.62      840
# 177             1.35             9.20  0.61   1.60      560
#
# [178 rows x 15 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['class_label'].plot(kind='hist', bins=20, title='class_label')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['alcohol'].plot(kind='hist', bins=20, title='alcohol')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['malic_acid'].plot(kind='hist', bins=20, title='malic_acid')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['ash'].plot(kind='hist', bins=20, title='ash')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('class_name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='class_label', y='alcohol', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='alcohol', y='malic_acid', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='malic_acid', y='ash', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='ash', y='alcalinity_of_ash', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['class_label']
#   ys = series['alcohol']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('class_label', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('class_name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='class_name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('class_label')
# _ = plt.ylabel('alcohol')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['class_label']
#   ys = series['malic_acid']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('class_label', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('class_name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='class_name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('class_label')
# _ = plt.ylabel('malic_acid')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['class_label']
#   ys = series['ash']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('class_label', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('class_name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='class_name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('class_label')
# _ = plt.ylabel('ash')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['class_label']
#   ys = series['alcalinity_of_ash']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('class_label', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('class_name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='class_name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('class_label')
# _ = plt.ylabel('alcalinity_of_ash')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['class_label'].plot(kind='line', figsize=(8, 4), title='class_label')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['alcohol'].plot(kind='line', figsize=(8, 4), title='alcohol')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['malic_acid'].plot(kind='line', figsize=(8, 4), title='malic_acid')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['ash'].plot(kind='line', figsize=(8, 4), title='ash')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['class_name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='class_label', y='class_name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['class_name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='alcohol', y='class_name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['class_name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='malic_acid', y='class_name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['class_name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='ash', y='class_name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# Step 3: Select features
y = wine_quality['alcohol']
X = wine_quality[['malic_acid']]  # prdict alchool content only using malic_acid....

# Step 4 : train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=2529)

# Step 5 : select model
model = LinearRegression()

# Step 6 : train or fit model
model.fit(X_train, y_train)

# Step 7 : predict model
y_pred_model_1 = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred_model_1)
r2 = r2_score(y_test, y_pred_model_1)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")

# Step 7 : plot results of the model
plt.scatter(y_test, y_pred_model_1)
plt.plot(y_test, y_test, c='r', label='perfect predictor')
plt.xlabel('y_test ')
plt.ylabel('y_pred ')
plt.legend()
plt.show()
print('clearly not a very good model')
# Out:
# Mean Squared Error: 0.6474073096998934
# R-squared: 0.011359379442903772
# clearly not a very good model

# %%
X = wine_quality[['malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium']]  # Repeat the same analysis but adding more input features (hopefully better predictions)

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=2529)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred_model_2 = model.predict(X_test)   # predictions of our 2nd model
mse = mean_squared_error(y_test, y_pred_model_2)
r2 = r2_score(y_test, y_pred_model_2)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")

plt.scatter(y_test, y_pred_model_2)
plt.plot(y_test, y_test, c='r', label='perfect predictor')
plt.xlabel('y_test ')
plt.ylabel('y_pred ')
plt.legend()
plt.show()

print('better....not optimal')
# Out:
# Mean Squared Error: 0.43259359024821675
# R-squared: 0.33939640608897237
# better....not optimal

# %%
X = wine_quality[names_inputs]  # Add all the features
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=2529)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred_model_3 = model.predict(X_test)  # predictions of our 3rd model
mse = mean_squared_error(y_test, y_pred_model_3)
r2 = r2_score(y_test, y_pred_model_3)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")

plt.scatter(y_test, y_pred_model_3)
plt.plot(y_test, y_test, c='r', label='perfect predictor')
plt.xlabel('y_test ')
plt.ylabel('y_pred ')
plt.legend()
plt.show()
print('more features....slowly improving....linear model is not ideal I suppose')
# Out:
# Mean Squared Error: 0.280908646609864
# R-squared: 0.5710309498467565
# more features....slowly improving....linear model is not ideal I suppose

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=2529)



# Initialize two non-linear regressors
rf_model = RandomForestRegressor(n_estimators=20, random_state=2529)
gb_model = GradientBoostingRegressor(n_estimators=20, random_state=2529)



# Fit the model to the training data
rf_model.fit(X_train, y_train)
gb_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred_rf = rf_model.predict(X_test)
y_pred_gb = gb_model.predict(X_test)

# Evaluate the models
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print(f"Random Forest Regressor - Mean Squared Error: {mse_rf}")
print(f"Random Forest Regressor - R-squared: {r2_rf}")

# Evaluate the model
mse_gb = mean_squared_error(y_test, y_pred_gb)
r2_gb = r2_score(y_test, y_pred_gb)

print(f"GB Regressor - Mean Squared Error: {mse_gb}")
print(f"GB Regressor - R-squared: {r2_gb}")

plt.scatter(y_test, y_pred_rf, 50, marker= f'$R$')
plt.scatter(y_test, y_pred_gb, 50, marker= f'$G$')
plt.plot(y_test, y_test, c='r', label='perfect predictor')
plt.xlabel('y_test ')
plt.ylabel('y_pred ')
plt.legend()
plt.grid()
plt.show()
print('non-linear models, slighly better')
# Out:
# Random Forest Regressor - Mean Squared Error: 0.18910874537037056
# Random Forest Regressor - R-squared: 0.7112164404470458
# GB Regressor - Mean Squared Error: 0.21666810935893788
# GB Regressor - R-squared: 0.6691311777266631
# non-linear models, slighly better

# %%
errors_1 = abs(y_pred_model_1-y_test)
errors_2 = abs(y_pred_model_2-y_test)
errors_3 = abs(y_pred_model_3-y_test)
errors_4 = abs(y_pred_rf-y_test)
errors_5 = abs(y_pred_gb-y_test)

# %%
import numpy as np

def ecdf(data):
  """Compute ECDF for a one-dimensional array of data."""
  # Number of data points: n
  n = len(data)
  # x-data for the ECDF: x
  x = np.sort(data)
  # y-data for the ECDF: y
  y = np.arange(1, n+1) / n
  return x, y

x_ecdf, y_ecdf = ecdf(errors_1)
plt.plot(x_ecdf, y_ecdf, ':', label='abs(errors) model 1')
x_ecdf, y_ecdf = ecdf(errors_2)
plt.plot(x_ecdf, y_ecdf, '.-', label='abs(errors) model 2')
x_ecdf, y_ecdf = ecdf(errors_3)
plt.plot(x_ecdf, y_ecdf, '--', label='abs(errors) model 3')
x_ecdf, y_ecdf = ecdf(errors_4)
plt.plot(x_ecdf, y_ecdf, '-x', label='abs(errors) model 4')
x_ecdf, y_ecdf = ecdf(errors_5)
plt.plot(x_ecdf, y_ecdf, '-v', label='abs(errors) model 5')
plt.xlabel('y_test')
plt.ylabel('ECDF')
plt.grid()
plt.legend()
plt.show()

# %%
def estimate_cvar_and_var(errors, probability_threshold):
  """Estimates Conditional Value at Risk (CVaR) and Value at Risk (VaR).

  Args:
    errors: A numpy array of prediction errors.
    probability_threshold: The desired probability threshold (e.g., 0.95 for 95%).

  Returns:
    A tuple containing the estimated CVaR and VaR.
  """
  var = errors.quantile(probability_threshold)
  cvar = np.mean(errors[errors>=var]) # right-tails
  return cvar, var


# Calculate CVaR and VaR for the three cases with a plevel % probability threshold
plevel= 0.5
cvar_1, var_1 = estimate_cvar_and_var(errors_1, plevel)
cvar_2, var_2 = estimate_cvar_and_var(errors_2, plevel)
cvar_3, var_3 = estimate_cvar_and_var(errors_3, plevel)
cvar_4, var_4 = estimate_cvar_and_var(errors_4, plevel)
cvar_5, var_5 = estimate_cvar_and_var(errors_5, plevel)

print(f"Model 1: Conditional VaR = {cvar_1:.4f}, Value at Risk = {var_1:.4f} probability level {plevel}")
print(f"Model 2: Conditional VaR = {cvar_2:.4f}, Value at Risk =  {var_2:.4f} probability level {plevel}")
print(f"Model 3: Conditional VaR = {cvar_3:.4f}, Value at Risk =  {var_3:.4f} probability level {plevel}")
print(f"Model 4: Conditional VaR = {cvar_4:.4f}, Value at Risk =  {var_4:.4f} probability level {plevel}")
print(f"Model 5: Conditional VaR = {cvar_5:.4f}, Value at Risk =  {var_5:.4f} probability level {plevel}")

print('interpretation: CVaR is an indicator of the riks of making large (severe) prediction errors')
# Out:
# Model 1: Conditional VaR = 1.0121, Value at Risk = 0.6590 probability level 0.5
# Model 2: Conditional VaR = 0.8228, Value at Risk =  0.4042 probability level 0.5
# Model 3: Conditional VaR = 0.6842, Value at Risk =  0.4532 probability level 0.5
# Model 4: Conditional VaR = 0.5462, Value at Risk =  0.3120 probability level 0.5
# Model 5: Conditional VaR = 0.5914, Value at Risk =  0.2925 probability level 0.5
# interpretation: CVaR is an indicator of the riks of making large (severe) prediction errors
